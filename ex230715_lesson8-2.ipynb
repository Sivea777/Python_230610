# %%
filename = '111年-雙溪區.csv'
file = open(filename,mode='r',encoding='utf-8',newline='')

# %%
import csv
csv_reader = csv.reader(file)
for row in csv_reader:
    print(row)
# Out:
# ['\ufeffdistrict', 'rps01', 'rps02', 'rps03', 'rps04', 'rps05', 'rps06', 'rps07', 'rps08', 'rps09', 'rps10', 'rps11', 'rps12', 'rps13', 'rps14', 'rps15', 'rps16', 'rps17', 'rps18', 'rps19', 'rps20', 'rps21', 'rps22', 'rps23', 'rps24', 'rps25', 'rps26', 'rps27', 'rps28', 'rps29', 'rps30', 'rps31']
# ['雙溪區', '土地', '平林段後番子坑小段431地號', '6876.25', '', '山坡地保育區', '林業用地', '1110103', '土地1建物0車位0', '', '', '其他', '', '', '', '0', '0', '0', '0', '有', '無', '2200398', '320', '', '0', '0', '親友、員工、共有人或其他特殊關係間之交易；', 'RPPNMLQJJHHGFFF77DA', '0', '0', '0', '無']
# ['雙溪區', '土地', '柑腳段柑腳小段98-1地號', '34', '', '山坡地保育區', '丙種建築用地', '1110107', '土地1建物0車位0', '', '', '其他', '', '', '', '0', '0', '0', '0', '有', '無', '102000', '3000', '', '0', '0', '親友、員工、共有人或其他特殊關係間之交易；', 'RPRNMLOKJHHGFFF97EA', '0', '0', '0', '無']
# ...

# %%
import csv
csv_reader = csv.reader(file)
data_all = list(csv_reader)
for item in data_all:
    print(item)
# Out:
# ['\ufeffdistrict', 'rps01', 'rps02', 'rps03', 'rps04', 'rps05', 'rps06', 'rps07', 'rps08', 'rps09', 'rps10', 'rps11', 'rps12', 'rps13', 'rps14', 'rps15', 'rps16', 'rps17', 'rps18', 'rps19', 'rps20', 'rps21', 'rps22', 'rps23', 'rps24', 'rps25', 'rps26', 'rps27', 'rps28', 'rps29', 'rps30', 'rps31']
# ['雙溪區', '土地', '平林段後番子坑小段431地號', '6876.25', '', '山坡地保育區', '林業用地', '1110103', '土地1建物0車位0', '', '', '其他', '', '', '', '0', '0', '0', '0', '有', '無', '2200398', '320', '', '0', '0', '親友、員工、共有人或其他特殊關係間之交易；', 'RPPNMLQJJHHGFFF77DA', '0', '0', '0', '無']
# ['雙溪區', '土地', '柑腳段柑腳小段98-1地號', '34', '', '山坡地保育區', '丙種建築用地', '1110107', '土地1建物0車位0', '', '', '其他', '', '', '', '0', '0', '0', '0', '有', '無', '102000', '3000', '', '0', '0', '親友、員工、共有人或其他特殊關係間之交易；', 'RPRNMLOKJHHGFFF97EA', '0', '0', '0', '無']
# ...

# %%
import csv
csv_reader = csv.reader(file)
data_all = list(csv_reader)
for item in data_all:
    if '柑腳段' in item[2]:
          print(item)
# Out:
# ['雙溪區', '土地', '柑腳段柑腳小段98-1地號', '34', '', '山坡地保育區', '丙種建築用地', '1110107', '土地1建物0車位0', '', '', '其他', '', '', '', '0', '0', '0', '0', '有', '無', '102000', '3000', '', '0', '0', '親友、員工、共有人或其他特殊關係間之交易；', 'RPRNMLOKJHHGFFF97EA', '0', '0', '0', '無']
# ['雙溪區', '土地', '柑腳段外柑腳小段49-2地號', '4347', '', '山坡地保育區', '農牧用地', '1101207', '土地1建物0車位0', '', '', '其他', '', '', '', '0', '0', '0', '0', '有', '無', '7510000', '1728', '', '0', '0', '', 'RPPNMLPJJHHGFFF77EA', '0', '0', '0', '無']
# ['雙溪區', '土地', '柑腳段柑腳小段98-4地號', '664.75', '', '山坡地保育區', '農牧用地', '1101115', '土地2建物0車位0', '', '', '其他', '', '', '', '0', '0', '0', '0', '有', '無', '2500000', '3761', '', '0', '0', '交易價格含地上未辦保存登記建物。未登記建物；', 'RPRNMLPJJHHGFFF97EA', '0', '0', '0', '無']
# ['雙溪區', '土地', '柑腳段外柑腳小段304地號', '433.33', '', '山坡地保育區', '丙種建築用地', '1110426', '土地1建物0車位0', '', '', '其他', '', '', '', '0', '0', '0', '0', '有', '無', '2151000', '4964', '', '0', '0', '地清或未辦繼承標售；', 'RPRNMLQLMHHGFFF58EA', '0', '0', '0', '無']
# ...

# %%
filename = 'aqx_p_432.csv'
aqi_file = open(filename,mode='r',newline='',encoding='utf-8')

# %%
import csv
csv_reader = csv.reader(aqi_file)
for row in aqi_file:
    print(row)
# Out:
# sitename,county,aqi,pollutant,status,so2,co,o3,o3_8hr,pm10,pm2.5,no2,nox,no,wind_speed,wind_direc,publishtime,co_8hr,pm2.5_avg,pm10_avg,so2_avg,longitude,latitude,siteid
#
# 基隆,基隆市,11,,良好,0.6,0.09,16.3,12.3,13,2,1,2.1,1.1,2.4,103,"2023/07/15 15:00:00",0.1,2,8,0,121.760056,25.129167,1
#
# 汐止,新北市,11,,良好,0.6,0.11,12.3,12.2,,1,2.7,5.5,2.8,2.4,154,"2023/07/15 15:00:00",0.1,0.5,,0,121.64081,25.06624,2
#
# 萬里,新北市,12,,良好,0.9,0.09,14,13.8,1,0,0.7,2.2,1.5,3,131,"2023/07/15 15:00:00",0,0.8,2,0,121.689881,25.179667,3
#
# 新店,新北市,14,,良好,0.8,0.06,15.1,15.6,9,0,2.6,4.1,1.5,4.4,127,"2023/07/15 15:00:00",0.1,1,9,0,121.537778,24.977222,4
#
# 土城,新北市,27,,良好,1,0.12,19.1,29.8,12,1,4.8,5.9,1.1,2.5,128,"2023/07/15 15:00:00",0.2,2.6,15,0,121.451861,24.982528,5
#
# 板橋,新北市,28,,良好,0.8,0.2,32,30,,7,8.2,9.9,1.6,2.4,131,"2023/07/15 15:00:00",0.2,4.9,,0,121.458667,25.012972,6
#
# 新莊,新北市,34,,良好,1.1,0.14,31.2,37.1,28,7,6.7,8.4,1.7,2.2,82,"2023/07/15 15:00:00",0.1,7.8,28,0,121.4325,25.037972,7
#
# ...

# %%
import csv
csv_reader = csv.reader(aqi_file)
data_AQI = list(csv_reader)
for item in data_AQI:
     print(item)

# %%
import csv
csv_reader = csv.reader(aqi_file)
data_AQI = list(csv_reader)
for item in data_AQI:
    if '臺北市' in item[1]:
          print(item)
# Out:
# ['士林', '臺北市', '15', '', '良好', '0.5', '0.06', '14.5', '16.3', '', '3', '2.6', '4.2', '1.6', '3.5', '144', '2023/07/15 15:00:00', '0', '2.5', '', '0', '121.51666356', '25.10334003', '11']
# ['中山', '臺北市', '14', '', '良好', '0', '0.13', '14.5', '15.2', '11', '0', '3.3', '6.2', '2.9', '3.7', '137', '2023/07/15 15:00:00', '0.1', '0.7', '9', '0', '121.526528', '25.062361', '12']
# ['萬華', '臺北市', '16', '', '良好', '0.5', '0.14', '14.5', '17.5', '9', '4', '5.1', '9.1', '3.9', '2', '122', '2023/07/15 15:00:00', '0.1', '3.9', '7', '0', '121.507972', '25.046503', '13']
# ['古亭', '臺北市', '14', '', '良好', '0.4', '0.05', '14.7', '15.4', '5', '1', '2.7', '4.6', '1.9', '4.4', '79', '2023/07/15 15:00:00', '0.1', '1.3', '6', '0', '121.529556', '25.020608', '14']
# ['松山', '臺北市', '11', '', '良好', '0.7', '0.1', '12', '12.2', '11', '0', '2.5', '5.5', '3', '2.9', '53', '2023/07/15 15:00:00', '0.1', '0', '7', '0', '121.578611', '25.05', '15']
# ...

# %%
#【方法1】篩選出空氣品質非良好的地區
import csv
csv_reader = csv.reader(aqi_file)
data_AQI = list(csv_reader)
for item in data_AQI:
    if not '良好' in item[4]:
          print(item)
# Out:
# ['\ufeffsitename', 'county', 'aqi', 'pollutant', 'status', 'so2', 'co', 'o3', 'o3_8hr', 'pm10', 'pm2.5', 'no2', 'nox', 'no', 'wind_speed', 'wind_direc', 'publishtime', 'co_8hr', 'pm2.5_avg', 'pm10_avg', 'so2_avg', 'longitude', 'latitude', 'siteid']
# ['桃園', '桃園市', '61', '臭氧八小時', '普通', '2.6', '0.22', '67.7', '58.4', '34', '9', '8.6', '9.6', '1', '2.2', '326', '2023/07/15 15:00:00', '0.2', '15.5', '33', '1', '121.30500531', '24.9947107', '17']
# ['平鎮', '桃園市', '54', '細懸浮微粒', '普通', '1.7', '0.28', '66', '52.3', '36', '16', '8.4', '9.8', '1.4', '2.4', '26', '2023/07/15 15:00:00', '0.2', '16.8', '34', '1', '121.203986', '24.952786', '20']
# ['龍潭', '桃園市', '53', '細懸浮微粒', '普通', '0.6', '0.27', '68', '55.5', '36', '18', '7.1', '8', '0.9', '2.4', '19', '2023/07/15 15:00:00', '0.2', '16.3', '31', '0', '121.21645772', '24.86400048', '21']
# ...

# %%
#【方法2】篩選出空氣品質非良好的地區
import csv
csv_reader = csv.reader(aqi_file)
data_AQI = list(csv_reader)
for item in data_AQI:
    if (item[4] != '良好'):
          print(item)
# Out:
# ['\ufeffsitename', 'county', 'aqi', 'pollutant', 'status', 'so2', 'co', 'o3', 'o3_8hr', 'pm10', 'pm2.5', 'no2', 'nox', 'no', 'wind_speed', 'wind_direc', 'publishtime', 'co_8hr', 'pm2.5_avg', 'pm10_avg', 'so2_avg', 'longitude', 'latitude', 'siteid']
# ['桃園', '桃園市', '61', '臭氧八小時', '普通', '2.6', '0.22', '67.7', '58.4', '34', '9', '8.6', '9.6', '1', '2.2', '326', '2023/07/15 15:00:00', '0.2', '15.5', '33', '1', '121.30500531', '24.9947107', '17']
# ['平鎮', '桃園市', '54', '細懸浮微粒', '普通', '1.7', '0.28', '66', '52.3', '36', '16', '8.4', '9.8', '1.4', '2.4', '26', '2023/07/15 15:00:00', '0.2', '16.8', '34', '1', '121.203986', '24.952786', '20']
# ['龍潭', '桃園市', '53', '細懸浮微粒', '普通', '0.6', '0.27', '68', '55.5', '36', '18', '7.1', '8', '0.9', '2.4', '19', '2023/07/15 15:00:00', '0.2', '16.3', '31', '0', '121.21645772', '24.86400048', '21']
# ...
